# %%
#9번
score=input('성적을 입력하시오.')
score=int(score)
if score>=60:
    print('합격')
else:
    print('불합격')
# Out:
# 합격

# %%
#10번
card=int(input('카드 잔액을 입력하세요:'))
if card>=1000:
    print('버스 탑승 가능')
else:
    print('버스 탑승 불가')
# Out:
# 버스 탑승 가능

# %%
#11번
capt=input('보안 문자 입력하세요:')
if capt=='N8SHA':
    print('비밀번호 찾기 허용')
else:
    print('비밀번호 찾기 허용 안함')
# Out:
# 비밀번호 찾기 허용

# %%
#12번
base=270
use=int(input('전기 사용량(kW)입력:'))
if use>100:
    cost=base*use*1.1
else:
    cost=base*use

print('전기 사용량:',use,'kW')
print('전기 요금:',cost,'원')
# Out:
# 전기 사용량: 80 kW
# 전기 요금: 21600 원

# %%
#13번
id=input('id를 입력하세요')
pwd=input('pud를 입력하세요')
if id=='info' and pwd=='edu':
    print('로그인 되었습니다.')
else:
    print('로그인에 실패했습니다')
# Out:
# 로그인 되었습니다.

# %%
#14번

kind=input('당신의 승객 유형은?[임상부, 노약자, 일반]')
if kind=='임산부' or kind=='노약자':
    print('이용 가능')
else:
    print('이용 불가능')
# Out:
# 이용 가능

# %%
#15번
kind=input('당신의 승객 유형은?[임상부, 노약자, 일반]')
if not kind=='일반':
    print('이용 가능')
else:
    print('이용 불가능')
# Out:
# 이용 가능

# %%
#16번

point=input('점수를 입력하세요.')
point=int(point)
if point>=90:
    print('A')
elif point>=80:
    print('B')
elif point>=70:
    print('C')
else:
    print('D')
# Out:
# B

# %%
#17번
num=int(input('정수를 입력하시오:'))
if num%2==0:
    print('짝수입니다.')
else:
    print('홀수입니다.')
# Out:
# 홀수입니다.

# %%
#18번
num=int(input('정수를 입력하시오:'))
if num>0:
    print('양수입니다')
elif num<0:
    print('음수입니다')
else:
    print('0입니다.')
# Out:
# 양수입니다

# %%
#19번
age=int(input('나이를 입력하세요:'))
cost=14000
'''
if age>=60:
    cost=14000*0.7
elif age<=10:
    cost=14000*0.8
'''
if age>=60 or age<=10:
    if age>=60:
        print('30%할인 대상입니다')
        cost=14000*0.7
    else:
        print('20%할인 대상입니다')
        cost=14000*0.8
else:
    print('할인대상이 아닙니다.')
print('찜질방 이용요금:',cost)
# Out:
# 할인대상이 아닙니다.
# 찜질방 이용요금: 14000

# %%
#20번
n1=int(input('첫 번째 정수:'))
n2=int(input('두 번째 정수:'))
if n1>n2:
    print(n1,'이(가) 더 큽니다.')
elif n2>n1:
    print(n2,'이(가) 더 큽니다.')
else:
    print(n1,'과',n2,'는 같습니다')
# Out:
# 13 이(가) 더 큽니다.

# %%
#21번
a=int(input('점수를 입력하세요:'))
if a>=60:
    print('합격입니다')
    if a>=90:
        print('장학금 대상')
else:
    print('불합격')
# Out:
# 합격입니다
