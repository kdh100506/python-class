# %%
'''
작성자: 홍길동
작성일: 03월09일
'''
print('소마고') #학교이름
# Out:
# 소마고

# %%
name=input('이름:')
age=int(input('나이:'))
print('제 이름은', name,'이고 나이는', age,'세 입니다.')
# Out:
# 제 이름은 김도현 이고 나이는 1234567890 세 입니다.

# %%
a=int(input('첫번쨰 숫자 입력:'))
b=int(input('두번쨰 숫자 입력:'))
print('두 숫자의 곱은', a*b,'입니다.')
# Out:
# 두 숫자의 곱은 144 입니다.

# %%
a=int(input('섭씨를 입력하시오:'))
b=a*1.8+32
print('섭씨',a ,'도는 화씨', b,'도 입니다.')
# Out:
# 섭씨 100 도는 화씨 212.0 도 입니다.

# %%
var=7
print(type(var))
# Out:
# <class 'int'>

# %%
j=3.14
print(type(j))
# Out:
# <class 'float'>

# %%
print(bool(1)) #1은 값이 있어서
print(bool(0)) #0은 값이 없어서
print(bool(None)) #None 이라서
print(bool("")) #빈 문자열 이여서
print(bool("Python")) #문자열에 Python이 있어서
# Out:
# True
# False
# False
# False
# True

# %%
print('''동해물과 백두산이
마르고 닳도록''')
# Out:
# 동해물과 백두산이
# 마르고 닳도록

# %%
i="파이썬"
j="문자열"

print(i+j)
print(i*3)
# Out:
# 파이썬문자열
# 파이썬파이썬파이썬

# %%
py='파이썬으로 코딩을 배우자!'
print(py[0])
print(py[6])
print(py[-1])
print(len(py))
# Out:
# 파
# 코
# !
# 14

# %%
korea='우리집 강아지 이름은 멍멍이 입니다.'
print(korea[4])
print(korea[4:7])
print(korea[:4])
print(korea[4:])
# Out:
# 강
# 강아지
# 우리집
# 강아지 이름은 멍멍이 입니다.

# %%
a='가나다라마바사'
print(a[:4])
print(a[2:5])
# Out:
# 가나다라
# 다라마
