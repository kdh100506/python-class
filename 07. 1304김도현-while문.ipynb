# %%
a=1
b=0

while a<=5:
    print(a)
    b=b+a
    a+=1
print(b)
# Out:
# 1
# 2
# 3
# 4
# 5
# 15

# %%
i=1
hap=0
while True:
    print(i)
    hap+=i
    if i>=5:
        break
    else:
        i+=1
print(hap)
# Out:
# 1
# 2
# 3
# 4
# 5
# 15

# %%
num2=0

while num2<=20:
    num=int(input('숫자:'))
    num2+=num
print('입력한 수의 합은',num2)
# Out:
# 입력한 수의 합은 123456789

# %%
num2=0

while True:
    num=int(input('숫자:'))
    if num<=20:
        num2+=num
    else:
        num2+=num
        break
print(num2)
# Out:
# 23

# %%
num=0
num2=0

while True:
    num=input('숫자:')
    if not num=='n':
        num2+=int(num)
        print(num)
    else:
        print('합계', num2)
        break
# Out:
# 4
# 3
# 4
# 3
# 43
# 4
# 34
# 343
# 43
# 43
# 34
# 343
# 434
# 34
# 43
# 343
# 434
# 3434
# 343
# 4
# 합계 5970

# %%
s=0
while True:
    num=input('숫자:')
    if num=='n':
        break
    num=int(num)
    print(num)
    s=s+num
print('합계:',s)
# Out:
# 212
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 320

# %%
#22번

i=1
while i<=5:
    print('Hello World')
    i+=1
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
#23번

i=1
sum=0
while i<=5:
    print(i)
    sum+=i
    i+=1
print('1~5까지의 합은:', sum)
# Out:
# 1
# 2
# 3
# 4
# 5
# 1~5까지의 합은: 15

# %%
#24번

sum=0
while sum<=20:
    n=int(input('숫자 입력:'))
    sum+=n
print('입력한 수의 합은:',sum)
# Out:
# 24

# %%
#25번

hap=0
while True:
    num=int(input('숫자 입력:'))
    hap+=num
    if hap>20:
        break
print('입력한 수의 합은:',hap)
# Out:
# 입력한 수의 합은: 24

# %%
#26번

point=0
sum=0
while sum<20:
    point=int(input('다트 점수를 입력하세요:'))
    print('이번 점수는',point)
    sum+=point
print('합계 점수는',sum)
# Out:
# 이번 점수는 12
# 이번 점수는 12
# 합계 점수는 24
