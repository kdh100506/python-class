# %%
#1

nums=[2,4,6,8]
for i in nums:
  print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
#2

nums=[5,10,15]
hap=0
for i in nums:
  hap+=i
print(hap)
# Out:
# 30

# %%
#3

nums=[1,2,3,4,5,6]
count=0
for i in nums:
  if i%2==0:
    count+=1
print(count)
# Out:
# 3

# %%
#4

nums=[3,15,7,20,9]
nums_=[]
for i in nums:
  if i>10:
    nums_.append(i)
    nums_.sort
print(nums_)
# Out:
# [15, 20]

# %%
#5

nums=[12,7,25,3,18]
nums.sort()
nums_len=len(nums)
print(nums[nums_len-1])
# Out:
# 25

# %%
#6

nums=[1,2,3,4]
nums_=[]
for i in nums:
  nums_.append(i**2)
print(nums_)
# Out:
# [1, 4, 9, 16]

# %%
#7

nums=[1,3,3,2,3,4]
print(nums.count(3))
# Out:
# 3

# %%
#8

nums=[10,20,30,40]
nums_len=len(nums)
nums_=[]
for i in range(nums_len,0,-1):
  nums_.append(nums[i-1])
print(nums_)
# Out:
# [40, 30, 20, 10]

# %%
#9

nums=[1,2,2,3,1,4,3]
nums.sort()
print(nums)
# Out:
# [1, 1, 2, 2, 3, 3, 4]

# %%
#10

a=[1,2,3,4,5]
b=[3,5,7,9]
c=[]

for i in a:
  for j in b:
    if i==j:
      c.append(i)
print(c)
# Out:
# [3, 5]

# %%
#11

nums=[4,9,2,9,1]
most_nums=nums.index(max(nums))
print(most_nums)
# Out:
# 1

# %%
#12

nums=[1,2,2,3,3,3,4]
nums_=[]
count=[]
print(1 in nums)
for i in nums:
  if not(i in nums_):
    a=nums.count(i)
    nums_.append(i)
    count.append(a)
b=max(count)
c=count.index(b)
d=nums_[c]
print(d)
# Out:
# True
# 3

# %%
#13

nums=[5,12,7,20,3,15]
nums_=[]
for i in nums:
  if i>=10:
    nums_.append(i)
print(nums_)
# Out:
# [12, 20, 15]

# %%
#14

words=['apple','kiwi','banana']
words_=[]
for i in words:
  a=len(i)
  words_.append(a)
print(words_)
# Out:
# [5, 4, 6]

# %%
#15

nums=[5,2,8,1,3]
nums_=[]
for i in nums:
  a=min(nums)
  nums_.append(a)
  b=nums.index(a)
  c=max(nums)
  nums[b]=c+1
print(nums_)
# Out:
# [1, 2, 3, 5, 8]

# %%
#15

nums=[5,2,8,1,3]
for i in range(len(nums)):
  for j in range(i+1,len(nums)):
    if nums[i]>nums[j]:
      nums[i],nums[j]=nums[j],nums[i]
print(nums)
# Out:
# [1, 2, 3, 5, 8]
