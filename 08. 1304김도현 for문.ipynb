# %%
for i in 'hello':
    print(i)

# %%
for i in range(1, 6):
    print(i)

# %%
for i in [1,3,5]:
    print(i, end=' ')

# %%
a=range(1,6)
for i in a:
    print(i, end=' ')

# %%
for i in 'Hello':
    print(i)
word='banana'
list(word)
type(word)

# %%
for i in range(1, 10):
    print('2x'+str(i),'=',2*i)

# %%
count=0
for s in 'banana':
    if s=='a':
        count+=1
print('a문자 포함횟수는', count)

# %%
for i in range(1,10):
    for j in range(1,10):
        print(i,'x',j,'=',i*j)

# %%
num=int(input('숫자 입력하세요:'))
sum=1
for i in range(1,num+1):
    sum*=i
    sum+=i
print(num,'!=',sum)
# Out:
# 12 != 1781062944
