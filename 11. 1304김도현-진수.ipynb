# %%
a,b=map(str,input().split())

if int(b)==1:
    print('현재 나이',2026-(int(a[0:2])+1900),'살 남성입니다')
elif int(b)==2:
    print('현재 나이',2026-(int(a[0:2])+1900),'살 여성입니다')
elif int(b)==3:
    print('현재 나이',2026-(int(a[0:2])+2000),'살 남성입니다')
elif int(b) ==4:
    print('현재 나이',2026-(int(a[0:2])+2000),'살 여성입니다')

# %%
su=int(input())
print(f'10진수 {su}=(문자){chr(su)}/(2진수){bin(su)}/(8진수){oct(su)}/(16진수){hex(su)}')

ch=input('문자 입력:')
ch_b=ord(ch)
print(f'(문자){ch}/(2진수){bin(ch_b)}/(8진수){oct(ch_b)}/(16진수){hex(ch_b)}')
# Out:
# 10진수 97=(문자)a/(2진수)0b1100001/(8진수)0o141/(16진수)0x61
# (문자)b/(2진수)0b1100010/(8진수)0o142/(16진수)0x62
