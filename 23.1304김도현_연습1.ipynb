# %%
#140

def f(n):
  k=0
  while k<n:
    k=k+1
    print(k)
f(2)
# Out:
# 1
# 2

# %%
def g(a):
  for i in range(a,0,-1):
    print(i)

g(8)
# Out:
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
def g(a):
  c=1
  for i in range(1,a+1):
    c*=i
  return c

g(10)
# Out:
# 3628800

# %%
s=10
def f(n):
  global s
  k=0
  while k<n:
    k+=1
    s+=k
f(4)
print(s)
# Out:
# 20

# %%
s=1
def g(a):
  global s
  for i in range(1,a+1):
    s*=i
  return s

g(4)
# Out:
# 24

# %%
def g(a):
  hap=0
  for i in range(0,a+1,2):
    hap+=i
  return hap

g(12)
# Out:
# 42
