# %%
print(1+1)
print(3/2)
print(5%2)
# Out:
# 2
# 1.5
# 1
# hello

# %%
print("hello")
# Out:
# hello

# %%
print('대구', '소마고', '홍길동')
print('대구'+'소마고'+'홍길동')
# Out:
# 대구 소마고 홍길동
# 대구소마고홍길동

# %%
print(3*6)
print('대구'*3)
print(2**10)
# Out:
# 18
# 대구대구대구
# 1024

# %%
print(5>3)
print(5<=3)
print(5==3)
print(5!=3)
# Out:
# True
# False
# False
# True

# %%
a=3 ##대입연산자
a=input('first:')
print(a)
# Out:
# 1

# %%
a=int(input('first:'))
b=int(input('second:'))

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# 7
# -1
# 12
# 0.75
# 3
# 0
# 81
